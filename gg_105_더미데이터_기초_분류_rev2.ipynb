# %% [markdown]
# <a href="https://colab.research.google.com/github/rtajeong/AI_Cluster_MSAC/blob/main/gg_105_%EB%8D%94%EB%AF%B8%EB%8D%B0%EC%9D%B4%ED%84%B0_%EA%B8%B0%EC%B4%88_%EB%B6%84%EB%A5%98_rev2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 분류 (Classification)

# %% [markdown]
# ## K Nearest Neighbors (k-최근접 이웃 분류 알고리즘)

# %% [markdown]
# 가장 중요한 hyperparameter인 **K**값은 근처에 참고(reference)할 **이웃의 숫자**

# %% [markdown]
# - k-최근접 이웃 분류 알고리즘
# - 가장 고전적이고 직관적인 머신러닝 분류 알고리즘
# - 기하학적 거리 분류기
# - 가장 **가깝게 위치하는 멤버로 분류**하는 방식

# %% [markdown]
# ## 더미 데이터를 활용한 분류 원리 이해

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import make_classification

# %%
5//3, 5/3
# Out:
# (1, 1.6666666666666667)

# %%
fig, axes = plt.subplots(3, 3)
fig.set_size_inches(10, 10)

for i in range(9):
    # 더미 데이터 생성
    X, y = make_classification(n_samples=50, n_features=2, n_informative=2, n_redundant=0, random_state=30)

    blue = X[y==0]
    red = X[y==1]

    # 랜덤한 새로운 점 생성
    newcomer = np.random.randn(1, 2)
    print(newcomer)

    # K
    K = 3*(i//3 + 1)


    axes[i//3, i%3].scatter(red[:, 0], red[:, 1], s=80, c='r', marker='^')
    axes[i//3, i%3].scatter(blue[:,0], blue[:, 1], s=80, c='b', marker='^')
    axes[i//3, i%3].scatter(newcomer[:, 0], newcomer[:, 1], s=80, c='g', marker='o')

    # n_neighbors=3
    knn = KNeighborsClassifier(n_neighbors=3*(i//3 + 1))
    knn.fit(X, y)
    pred = knn.predict(newcomer)

    # 표기
    axes[i//3, i%3].annotate('red' if pred==1 else 'blue', xy=newcomer[0], xytext=(newcomer[0]+(-0.2,0.2)), fontsize=12)
    axes[i//3, i%3].text(2.3, 2.3, 'K={}'.format(K))

plt.tight_layout()
plt.show()
# Out:
# [[0.07782113 0.61838026]]
# [[0.23249456 0.68255141]]
# [[-0.31011677 -2.43483776]]
# [[1.0388246  2.18697965]]
# [[ 0.44136444 -0.10015523]]
# [[-0.13644474 -0.11905419]]
# [[ 0.01740941 -1.12201873]]
# [[-0.51709446 -0.99702683]]
# [[ 0.24879916 -0.29664115]]

# %%
for i in range(1,12):
    model = KNeighborsClassifier(i)
    model.fit(X,y)
    print("K = {}: ".format(i), model.score(X,y))
# Out:
# K = 1:  1.0
# K = 2:  0.94
# K = 3:  0.96
# K = 4:  0.96
# K = 5:  0.96
# K = 6:  0.92
# K = 7:  0.94
# K = 8:  0.92
# K = 9:  0.92
# K = 10:  0.92
# K = 11:  0.92
