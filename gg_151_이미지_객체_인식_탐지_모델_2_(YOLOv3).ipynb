# %% [markdown]
# <a href="https://colab.research.google.com/github/rtajeong/AI_Cluster_MSAC/blob/main/gg_151_%EC%9D%B4%EB%AF%B8%EC%A7%80_%EA%B0%9D%EC%B2%B4_%EC%9D%B8%EC%8B%9D_%ED%83%90%EC%A7%80_%EB%AA%A8%EB%8D%B8_2_(YOLOv3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
print(sys.version)
# Out:
# 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]

# %% [markdown]
# # Setup

# %%
# !git clone https://github.com/ultralytics/yolov3.git
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 12452, done.
# remote: Counting objects: 100% (142/142), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 12452 (delta 101), reused 63 (delta 63), pack-reused 12310 (from 3)
# Receiving objects: 100% (12452/12452), 10.96 MiB | 24.14 MiB/s, done.
# Resolving deltas: 100% (8406/8406), done.

# %%
# %cd yolov3
# !pip install -r requirements.txt
# Out:
# /content/yolov3
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 36.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Inference

# %%
# not needed anymore (automatically downloaded)
# !chmod +x weights/download_weights.sh
# !weights/download_weights.sh

# %%
# !python3 detect.py
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# detect: weights=yolov3-tiny.pt, source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv3 🚀 v9.6.0-290-g83804a1 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# ...
# 100% 17.0M/17.0M [00:00<00:00, 55.3MB/s]
#
# Fusing layers...
# ...

# %% [markdown]
# - 위 코드를 실행하면 이미 사전에 훈련된 모델을 불러 오고 자동으로 환경이 설정된다.
# - 결과 이미지는 runs/detect/exp 밑에 저장된다.
# - 속도가 빠른 것을 확인할 수 있다.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('./runs/detect/exp/bus.jpg')
plt.imshow(img)

# %%
img = mpimg.imread('./runs/detect/exp/zidane.jpg')
plt.imshow(img)

# %% [markdown]
# ## using Yolov3-tiny

# %%
# !python3 detect.py --weights yolov3-tiny.pt
img = mpimg.imread('./runs/detect/exp/bus.jpg')
plt.imshow(img)
# Out:
# detect: weights=['yolov3-tiny.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv3 🚀 v9.6.0-290-g83804a1 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# yolov3-tiny summary: 48 layers, 8849182 parameters, 0 gradients, 13.2 GFLOPs
# image 1/2 /content/yolov3/data/images/bus.jpg: 640x480 4 persons, 1 bus, 1 skateboard, 1 surfboard, 12.9ms
# image 2/2 /content/yolov3/data/images/zidane.jpg: 384x640 3 persons, 1 tie, 14.0ms
# Speed: 0.4ms pre-process, 13.5ms inference, 33.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
img = mpimg.imread('./runs/detect/exp/zidane.jpg')
plt.imshow(img)
